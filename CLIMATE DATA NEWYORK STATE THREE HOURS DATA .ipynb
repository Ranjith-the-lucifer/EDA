# %% [markdown]
# # CLIMATE DATA NEWYORK STATE DATA ANALYSIS

# %% [markdown]
# # DATA PREPARTION

# %%
# 1.LOAD THE file USING PANDAS
# 2.LOOK AT SOME INFORMATION ABOUT THE DATA AND THE COLUMNS
# 3.FIX ANY MISSING AND INCORRECT VALUES

# %%
#import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/ambee/OneDrive/Desktop/three_hour_data.csv")

# %%
df
# Out:
#            STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0      72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1      72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2      72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3      72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4      72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
# ...            ...                  ...         ...     ...            ...
# 20838  72518014735  2022-05-31T10:00:00       FM-12       4         PRECIP
# 20839  72518014735  2022-05-31T13:00:00       FM-12       4         PRECIP
# 20840  72518014735  2022-05-31T16:00:00       FM-12       4         PRECIP
# 20841  72518014735  2022-05-31T19:00:00       FM-12       4         PRECIP
# 20842  72518014735  2022-05-31T22:00:00       FM-12       4         PRECIP
#
# ...

# %%
df.shape
# Out:
# (20843, 22)

# %%
df.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %%
df.tail()
# Out:
#            STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 20838  72518014735  2022-05-31T10:00:00       FM-12       4         PRECIP
# 20839  72518014735  2022-05-31T13:00:00       FM-12       4         PRECIP
# 20840  72518014735  2022-05-31T16:00:00       FM-12       4         PRECIP
# 20841  72518014735  2022-05-31T19:00:00       FM-12       4         PRECIP
# 20842  72518014735  2022-05-31T22:00:00       FM-12       4         PRECIP
#
#        BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 20838              260         PLASTIC         42.6812         -73.8165
# 20839              260         PLASTIC         42.6812         -73.8165
# 20840              260         PLASTIC         42.6812         -73.8165
# 20841              260         PLASTIC         42.6812         -73.8165
# 20842              260         PLASTIC         42.6812         -73.8165
#
#            BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %%
df.columns
# Out:
# Index(['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements',
#        'BackupElevation', 'BackupEquipment', 'BackupLatitude',
#        'BackupLongitude', 'BackupName', 'HourlyDewPointTemperature',
#        'HourlyDryBulbTemperature', 'HourlyPressureChange',
#        'HourlyPressureTendency', 'HourlyRelativeHumidity',
#        'HourlySeaLevelPressure', 'HourlyStationPressure', 'HourlyVisibility',
#        'HourlyWetBulbTemperature', 'HourlyWindDirection', 'HourlyWindSpeed',
#        'WindEquipmentChangeDate'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 22

# %%
#data set contains 22 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20843 entries, 0 to 20842
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATION                    20843 non-null  int64
#  1   DATE                       20843 non-null  object
#  2   REPORT_TYPE                20843 non-null  object
#  3   SOURCE                     20843 non-null  int64
#  4   BackupElements             20843 non-null  object
#  5   BackupElevation            20843 non-null  int64
#  6   BackupEquipment            20843 non-null  object
#  7   BackupLatitude             20843 non-null  float64
#  8   BackupLongitude            20843 non-null  float64
#  9   BackupName                 20843 non-null  object
#  10  HourlyDewPointTemperature  20843 non-null  object
#  11  HourlyDryBulbTemperature   20843 non-null  object
#  12  HourlyPressureChange       20843 non-null  float64
# ...

# %%
#dataset contains 20842 entries and 22 columns and the entries with different dtypes float,int,object

# %%
df.describe()
# Out:
#             STATION   SOURCE  BackupElevation  BackupLatitude  \
# count  2.084300e+04  20843.0          20843.0    20843.000000
# mean   7.251801e+10      4.0            260.0       42.689777
# std    0.000000e+00      0.0              0.0        0.004166
# min    7.251801e+10      4.0            260.0       42.681200
# 25%    7.251801e+10      4.0            260.0       42.691800
# 50%    7.251801e+10      4.0            260.0       42.691800
# 75%    7.251801e+10      4.0            260.0       42.691800
# max    7.251801e+10      4.0            260.0       42.691800
#
#        BackupLongitude  HourlyPressureChange  HourlyPressureTendency  \
# count     20843.000000          20843.000000            20843.000000
# mean        -73.828305              0.001490                4.907835
# std           0.005734              0.049271                2.762154
# min         -73.831090             -0.320000                1.000000
# ...

# %%
numeric=['int16','int32','int64','float16','float32','float64']
numeric_df=df.select_dtypes(include=numeric)
len(numeric_df.columns)
# Out:
# 12

# %%
# the dataset contains 12 numeric data types columns

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Missing and Incorrect values

# %%
df.isna()
# Out:
#        STATION   DATE  REPORT_TYPE  SOURCE  BackupElements  BackupElevation  \
# 0        False  False        False   False           False            False
# 1        False  False        False   False           False            False
# 2        False  False        False   False           False            False
# 3        False  False        False   False           False            False
# 4        False  False        False   False           False            False
# ...        ...    ...          ...     ...             ...              ...
# 20838    False  False        False   False           False            False
# 20839    False  False        False   False           False            False
# 20840    False  False        False   False           False            False
# 20841    False  False        False   False           False            False
# 20842    False  False        False   False           False            False
#
# ...

# %%
df.isna().sum()
# Out:
# STATION                      0
# DATE                         0
# REPORT_TYPE                  0
# SOURCE                       0
# BackupElements               0
# BackupElevation              0
# BackupEquipment              0
# BackupLatitude               0
# BackupLongitude              0
# BackupName                   0
# HourlyDewPointTemperature    0
# HourlyDryBulbTemperature     0
# HourlyPressureChange         0
# HourlyPressureTendency       0
# HourlyRelativeHumidity       0
# HourlySeaLevelPressure       0
# HourlyStationPressure        0
# HourlyVisibility             0
# HourlyWetBulbTemperature     0
# HourlyWindDirection          0
# HourlyWindSpeed              0
# WindEquipmentChangeDate      0
# dtype: int64

# %%
# the dataset doesnot contain any missing and incorrect values in each column

# %%
df.isna().sum()/len(df)
# Out:
# STATION                      0.0
# DATE                         0.0
# REPORT_TYPE                  0.0
# SOURCE                       0.0
# BackupElements               0.0
# BackupElevation              0.0
# BackupEquipment              0.0
# BackupLatitude               0.0
# BackupLongitude              0.0
# BackupName                   0.0
# HourlyDewPointTemperature    0.0
# HourlyDryBulbTemperature     0.0
# HourlyPressureChange         0.0
# HourlyPressureTendency       0.0
# HourlyRelativeHumidity       0.0
# HourlySeaLevelPressure       0.0
# HourlyStationPressure        0.0
# HourlyVisibility             0.0
# HourlyWetBulbTemperature     0.0
# HourlyWindDirection          0.0
# HourlyWindSpeed              0.0
# WindEquipmentChangeDate      0.0
# dtype: float64

# %%
#percentage of missing values per columns

# %% [markdown]
# # Data Analysis

# %%
df.describe()
# Out:
#             STATION   SOURCE  BackupElevation  BackupLatitude  \
# count  2.084300e+04  20843.0          20843.0    20843.000000
# mean   7.251801e+10      4.0            260.0       42.689777
# std    0.000000e+00      0.0              0.0        0.004166
# min    7.251801e+10      4.0            260.0       42.681200
# 25%    7.251801e+10      4.0            260.0       42.691800
# 50%    7.251801e+10      4.0            260.0       42.691800
# 75%    7.251801e+10      4.0            260.0       42.691800
# max    7.251801e+10      4.0            260.0       42.691800
#
#        BackupLongitude  HourlyPressureChange  HourlyPressureTendency  \
# count     20843.000000          20843.000000            20843.000000
# mean        -73.828305              0.001490                4.907835
# std           0.005734              0.049271                2.762154
# min         -73.831090             -0.320000                1.000000
# ...

# %% [markdown]
# # max and min value gives the max and min climate change of each cause and mean values gives the average climate change of each cause

# %% [markdown]
# # for example HourlyPressureChange have the 0.310000 is the max value and 0.320000 is the min value and 0.320000 is the mean value

# %%
df.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %% [markdown]
# # Exploratory analysis and Visualization

# %% [markdown]
# # Univarite
# # Bivarite
# # Statistical analysis
# # Multivariate analysis

# %%
# analysis of HourlyDewPOintTemperature
df.HourlyDewPointTemperature.value_counts()
# Out:
# 31     442
# 29     404
# 32     393
# 30     389
# 61     388
#       ...
# -26      1
# -27      1
# 77       1
# 51s      1
# -2s      1
# Name: HourlyDewPointTemperature, Length: 102, dtype: int64

# %%
df.HourlyDewPointTemperature.unique()
# Out:
# array(['4', '6', '7', '8', '10', '14', '15', '17', '18', '19', '16', '13',
#        '11', '21', '23', '29', '30', '31', '34', '36', '38', '40', '27',
#        '20', '9', '1', '2', '-1', '0', '-6', '-13', '-14', '-16', '-17',
#        '-15', '-9', '-2', '5', '-3', '-4', '3', '25', '28', '-7', '-10',
#        '-12', '-5', '-8', '-11', '32', '37', '26', '12', '24', '22',
#        '-19', '-18', '-20', '33', '35', '39', '41', '47', '45', '42',
#        '43', '46', '44', '50', '48', '51', '52', '53', '55', '49', '59',
#        '61', '60', '62', '66', '63', '65', '64', '56', '54', '57', '58',
#        '67', '68', '71', '70', '69', '72', '74', '-25', '-27', '-26',
#        '73', '75', '77', '51s', '-2s'], dtype=object)

# %%
len(df.HourlyDewPointTemperature.unique())
# Out:
# 102

# %%
df['HourlyDewPointTemperature']=df['HourlyDewPointTemperature'].str.strip('s')

# %%
df.head()
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T01:00:00       FM-12       4         PRECIP
# 1  72518014735  2015-01-01T04:00:00       FM-12       4         PRECIP
# 2  72518014735  2015-01-01T07:00:00       FM-12       4         PRECIP
# 3  72518014735  2015-01-01T10:00:00       FM-12       4         PRECIP
# 4  72518014735  2015-01-01T13:00:00       FM-12       4         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
# 3              260         PLASTIC         42.6918        -73.83109
# 4              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ... HourlyPressureChange HourlyPressureTendency  \
# ...

# %%
df.HourlyDewPointTemperature.unique()
# Out:
# array(['4', '6', '7', '8', '10', '14', '15', '17', '18', '19', '16', '13',
#        '11', '21', '23', '29', '30', '31', '34', '36', '38', '40', '27',
#        '20', '9', '1', '2', '-1', '0', '-6', '-13', '-14', '-16', '-17',
#        '-15', '-9', '-2', '5', '-3', '-4', '3', '25', '28', '-7', '-10',
#        '-12', '-5', '-8', '-11', '32', '37', '26', '12', '24', '22',
#        '-19', '-18', '-20', '33', '35', '39', '41', '47', '45', '42',
#        '43', '46', '44', '50', '48', '51', '52', '53', '55', '49', '59',
#        '61', '60', '62', '66', '63', '65', '64', '56', '54', '57', '58',
#        '67', '68', '71', '70', '69', '72', '74', '-25', '-27', '-26',
#        '73', '75', '77'], dtype=object)

# %%
len(df.HourlyDewPointTemperature.unique())
# Out:
# 100

# %%
df['HourlyDewPointTemperature']=df['HourlyDewPointTemperature'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20843 entries, 0 to 20842
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATION                    20843 non-null  int64
#  1   DATE                       20843 non-null  object
#  2   REPORT_TYPE                20843 non-null  object
#  3   SOURCE                     20843 non-null  int64
#  4   BackupElements             20843 non-null  object
#  5   BackupElevation            20843 non-null  int64
#  6   BackupEquipment            20843 non-null  object
#  7   BackupLatitude             20843 non-null  float64
#  8   BackupLongitude            20843 non-null  float64
#  9   BackupName                 20843 non-null  object
#  10  HourlyDewPointTemperature  20843 non-null  float64
#  11  HourlyDryBulbTemperature   20843 non-null  object
#  12  HourlyPressureChange       20843 non-null  float64
# ...

# %%
df['HourlyDewPointTemperature'].value_counts().plot(kind = 'bar',color="Green",figsize=(20,10))
plt.xlabel("HourlyDewPointTemperature",fontdict={'fontsize':12,'fontweight':3,'color':'Blue'})
plt.ylabel("occurence of dewpointtemperature",fontdict={'fontsize':12,'fontweight':3,'color':'Blue'})
plt.show()

# %% [markdown]
# # From the above graph we can conclude that 31Cis the most number of hourlydewpoint temperature occurence and 77C is the least hourlydewpoint temperature

# %%
df.HourlyDewPointTemperature.describe()
# Out:
# count    20843.000000
# mean        37.659022
# std         19.876538
# min        -27.000000
# 25%         23.000000
# 50%         38.000000
# 75%         55.000000
# max         77.000000
# Name: HourlyDewPointTemperature, dtype: float64

# %% [markdown]
# # max value of hourlydewpointtemperature is 77.000000 , min value is 27.000000 and mean value is 37.659022

# %% [markdown]
# # now lets fetch the details of that which has the max number of HourlyDewPointTemperature

# %%
df[df['HourlyDewPointTemperature'] == df.HourlyDewPointTemperature.max()][['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements','BackupElevation','BackupEquipment', 'BackupLatitude',]]
# Out:
#           STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 4546  72518014735  2016-08-13T16:00:00       FM-12       4         PRECIP
#
#       BackupElevation BackupEquipment  BackupLatitude
# 4546              260         PLASTIC         42.6918

# %%
df.HourlyDewPointTemperature.plot(kind="box",figsize=(10,15))
plt.ylabel("no of tempersture record")
plt.show()

# %% [markdown]
# # analysis of hourlywindspeed

# %%
df.HourlyWindSpeed
# Out:
# 0        10
# 1         7
# 2         9
# 3        11
# 4        15
#          ..
# 20838    13
# 20839     8
# 20840    18
# 20841    11
# 20842     7
# Name: HourlyWindSpeed, Length: 20843, dtype: int64

# %%
len(df.HourlyWindSpeed)
# Out:
# 20843

# %%
df.HourlyWindSpeed.value_counts()
# Out:
# 0     3914
# 5     1881
# 3     1857
# 6     1710
# 7     1663
# 8     1630
# 9     1476
# 10    1248
# 11    1095
# 13     905
# 14     763
# 15     617
# 16     501
# 17     393
# 18     346
# 20     239
# 21     172
# 22     132
# 23     101
# 24      63
# 25      49
# 28      28
# 26      26
# 29      17
# 31       6
# 30       6
# 32       2
# 33       2
# 38       1
# Name: HourlyWindSpeed, dtype: int64

# %%
df.HourlyWindSpeed.unique()
# Out:
# array([10,  7,  9, 11, 15,  0,  3, 14,  8,  5, 20, 25, 13,  6, 28, 16, 18,
#        17, 22, 24, 21, 26, 29, 23, 31, 30, 32, 33, 38], dtype=int64)

# %%
len(df.HourlyWindSpeed.unique())
# Out:
# 29

# %%
df.HourlyWindSpeed.describe()
# Out:
# count    20843.000000
# mean         7.637864
# std          5.768944
# min          0.000000
# 25%          3.000000
# 50%          7.000000
# 75%         11.000000
# max         38.000000
# Name: HourlyWindSpeed, dtype: float64

# %% [markdown]
# # max value of hourlywindspeed is 38.000000 knots(kt),min value of hourlywindspeed is 0.000000 and mean value is 7.637864

# %%
sns.boxplot(df.HourlyWindSpeed)
plt.show()

# %% [markdown]
# # we saw that HourlyWindSpeed has the outlier ,so let us ignore the outlier

# %%
df['HourlyWindSpeed'].value_counts().plot(kind = 'bar',color="Blue",figsize=(23,12))
plt.xlabel("HourlyWindSpeed",fontdict={'fontsize':16,'fontweight':7,'color':'Blue'})
plt.ylabel("occurence of HourlyWindSpeed",fontdict={'fontsize':17,'fontweight':7,'color':'Green'})
plt.show()

# %% [markdown]
# # from the graph we can conclude that 0kts(knots) is the most in number where as 38kts is the least in number

# %%
df.HourlyWindSpeed.plot(kind="box",figsize=(10,15))
plt.ylabel("number of hourlywindspeed")
plt.show()

# %% [markdown]
# # There is only one value which is above 35 and that is the maximum value and there are only a few values which are above 30.Most of the values lie in between 0 to 25.From this we can infer that most Hourlywindspeed from 0 to 25.

# %% [markdown]
# # now lets fetch the details of that which has the max number HourlyWindSpeed

# %%
df[df['HourlyWindSpeed'] == df.HourlyWindSpeed.max()][['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements','BackupElevation', 'BackupEquipment', 'BackupLatitude']],
# Out:
# (           STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
#  11690  72518014735  2019-02-25T10:00:00       FM-12       4         PRECIP
#
#         BackupElevation BackupEquipment  BackupLatitude
#  11690              260         PLASTIC         42.6918  ,)

# %% [markdown]
# # Analysis of HourlyPressureTendency

# %%
df.HourlyPressureTendency
# Out:
# 0        8
# 1        6
# 2        1
# 3        3
# 4        8
#         ..
# 20838    8
# 20839    6
# 20840    6
# 20841    3
# 20842    1
# Name: HourlyPressureTendency, Length: 20843, dtype: int64

# %%
df.HourlyPressureTendency.value_counts()
# Out:
# 3    4888
# 8    4794
# 1    3927
# 6    3345
# 9    1606
# 5    1499
# 2     364
# 7     308
# 4     112
# Name: HourlyPressureTendency, dtype: int64

# %%
len(df.HourlyPressureTendency)
# Out:
# 20843

# %%
df.HourlyPressureTendency.unique()
# Out:
# array([8, 6, 1, 3, 9, 5, 2, 7, 4], dtype=int64)

# %%
len(df.HourlyPressureTendency.unique())
# Out:
# 9

# %%
df.HourlyPressureTendency.describe()
# Out:
# count    20843.000000
# mean         4.907835
# std          2.762154
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max          9.000000
# Name: HourlyPressureTendency, dtype: float64

# %% [markdown]
# # from that we can conclude that 9.000000 is max pascal(pa) value, 1.000000 is min pascal(pa) value and 4.907835 is the mean value

# %%
df.HourlyPressureTendency.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# # from the pie chart we can say the 3pascal is most in frequency and 4 pascal is less in frequency

# %%
df['HourlyPressureTendency'].value_counts().plot(kind = 'bar',color="Red",figsize=(23,12))
plt.xlabel("HourlyPressureTendency",fontdict={'fontsize':16,'fontweight':7,'color':'Red'})
plt.ylabel("occurence of HourlyPressureTendency",fontdict={'fontsize':17,'fontweight':7,'color':'Blue'})
plt.show()

# %% [markdown]
# # from the we can conclude that 3pascals(pa) is the most,4Pascals(pa) is the least

# %%
sns.boxplot(df.HourlyPressureTendency)
plt.show()

# %% [markdown]
# # Now lets fetch the details of that which has the max number of HourlyPressureTendency

# %%
df[df['HourlyPressureTendency'] == df.HourlyPressureTendency.max()][['STATION', 'DATE', 'REPORT_TYPE', 'SOURCE', 'BackupElements','BackupElevation', 'BackupEquipment', 'BackupLatitude']],
# Out:
# (           STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
#  6      72518014735  2015-01-01T19:00:00       FM-12       4         PRECIP
#  19     72518014735  2015-01-03T10:00:00       FM-12       4         PRECIP
#  39     72518014735  2015-01-05T22:00:00       FM-12       4         PRECIP
#  51     72518014735  2015-01-07T10:00:00       FM-12       4         PRECIP
#  57     72518014735  2015-01-08T04:00:00       FM-12       4         PRECIP
#  ...            ...                  ...         ...     ...            ...
#  20791  72518014735  2022-05-25T10:00:00       FM-12       4         PRECIP
#  20797  72518014735  2022-05-26T07:00:00       FM-12       4         PRECIP
#  20829  72518014735  2022-05-30T07:00:00       FM-12       4         PRECIP
#  20834  72518014735  2022-05-30T22:00:00       FM-12       4         PRECIP
#  20837  72518014735  2022-05-31T07:00:00       FM-12       4         PRECIP
#
#         BackupElevation BackupEquipment  BackupLatitude
# ...

# %%
fig = plt.figure(figsize = (20,20))
sns.heatmap(df.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# # Heatmap: Heatmaps are used to show relationships
# # between two variables, one plotted on each axis. By observing
# # how cell colors change across each axis, you can observe if
# # there are any patterns in value for one or both variables. The
# # variables plotted on each axis can be of any type, whether they
# # take on categorical labels or numeric values

# %% [markdown]
# # Observations:(hourlywindspeed,hourlyvisibility),(hourlywinddire
# # ction,hourlywindspeed),(hourlywetbulbtemperature,hourlydewp
# # ointtemperature),(,hourlydewpointtemperature),(hourlypressure
# # tendency,hourlydewpointtemperature),(hourlypressurechange,h
# # ourlypressuretendency),(hourlydewpointtemperature,hourlywet
# # bulbtemperature),(backuplogitude,hourlyrelativehumidity),(back
# # uplatitude,hourlydewpointtemperature)
# # Have correlation value almost equal to 1
# # If the correlation value is equal to 1 then we can say that the
# # two variables are equal so I started my analysis with
# # HourlyPressureTendency, HourlyRelativeHumidity, HourlyVisibility,HourlyVisibility

# %%
df.groupby('HourlyPressureTendency')["HourlyWindSpeed"].mean().plot(kind = "bar",figsize=(19,9))
plt.ylabel("Avg.HourlyWindSpeed")
plt.show()

# %% [markdown]
# # from the above graph we can see that 4Pascals is the least in hourlywindspeed and 8 pascals is the highest in the hourlywindspeed

# %% [markdown]
# # lets check highest HourlyWindSpeed in 72518014735 Station

# %%
df_72518014735 = df[df['STATION'] == 72518014735]

# %%
len(df_72518014735)
# Out:
# 20843

# %%
#lets check houlrywindspeed in the station 72518014735 date wise
df_72518014735.groupby('DATE').mean()['HourlyWindSpeed'].plot(kind='line',figsize=(30,20))
plt.ylabel("Avg.HourlyWindSpeed")
plt.title("Avg. WindSpeed date in the station 72518014735")
plt.show()

# %% [markdown]
# # from the above graph we can conclude that 2019 year have the highest hourlywindspeed in the station 72518014735

# %%
#lets check most backuplatitude in the stationd
df_72518014735.BackupLatitude.value_counts()
# Out:
# 42.6918    16865
# 42.6812     3978
# Name: BackupLatitude, dtype: int64

# %%
df_72518014735['BackupLatitude'].value_counts().plot(kind = "bar",figsize=(20,10))
plt.xlabel("backuplatitude",fontdict={'fontsize':12,'fontweight':3,'color':'Blue'})
plt.ylabel("No.Of backuplatitude",fontdict={'fontsize':12,'fontweight':3,'color':'Blue'})
plt.show()

# %% [markdown]
# # 42.6918 latitude have in the most number

# %%
#Lets plot the graph for HourlyRelativeHumidity and HourlyPressureTendency columns.
df.groupby("HourlyRelativeHumidity")["HourlyPressureTendency"].mean().plot(kind='bar',figsize=(20,10))
plt.ylabel("Avg. hourlypressuretendecy")
plt.title("Avg. Number hourlypressuretendency in hourlyrelativehumidity")
plt.show()

# %% [markdown]
# # from the graph we can conclude  22 hourlyRelativeHumidity have the highest hourlypressuretendency

# %%
# now plot a graph for month vs weather_delay
df.groupby("HourlyRelativeHumidity")["HourlyPressureTendency"].mean().plot(kind = 'line', figsize=(20,10))
plt.ylabel("avg hourlypressuretendency")
plt.show()

# %% [markdown]
# # from the above graph we can conclude  22 hourlyRelativeHumidity have the highest hourlypressuretendency

# %%
sns.pairplot(df)
plt.show()

# %%
#pair plot of the data

# %% [markdown]
# ## a pair plot is a matrix of scatterplots that lets you understand the pairwaise relationship between different varibles in the data set
